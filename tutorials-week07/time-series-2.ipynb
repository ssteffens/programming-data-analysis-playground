# %%
# Import pandas module which contains time series functionalities
import pandas as pd

# %%
# Read in data, using first 1000 rows. Skippng first 17 rows in file containing additional information

# df = pd.read_csv('https://cli.fusio.net/cli/climate_data/webdata/hly2175.csv', skiprows=17, low_memory=False, nrows=1000)

df = pd.read_csv('https://cli.fusio.net/cli/climate_data/webdata/hly2175.csv', skiprows=17, low_memory=False)

# %%
df
# Out:
#                   date  ind  rain  ind.1  temp  ind.2  wetb  dewpt  vappr  \
# 0    01-jan-1991 00:00    3   0.0      0   1.5      0   1.0    0.2    6.2
# 1    01-jan-1991 01:00    3   0.0      0   1.8      0   1.3    0.5    6.3
# 2    01-jan-1991 02:00    0   0.0      0   2.1      0   1.8    1.3    6.7
# 3    01-jan-1991 03:00    2   0.0      0   2.5      0   2.2    1.7    6.9
# 4    01-jan-1991 04:00    0   0.2      0   3.4      0   2.9    2.1    7.1
# ..                 ...  ...   ...    ...   ...    ...   ...    ...    ...
# 995  11-feb-1991 11:00    0   0.0      0   3.2      0   2.3    0.8    6.5
# 996  11-feb-1991 12:00    0   0.0      0   5.5      0   3.6    0.6    6.4
# 997  11-feb-1991 13:00    0   0.0      0   6.6      0   4.4    1.0    6.6
# 998  11-feb-1991 14:00    0   0.0      0   6.5      0   3.9   -0.2    6.0
# 999  11-feb-1991 15:00    0   0.0      0   6.0      0   3.5   -0.6    5.8
#
#      rhum     msl  ind.3  wdsp  ind.4  wddir
# ...

# %%
# First column is data type object but should rather be date/time
# Define additional column 

df['datetime'] = pd.to_datetime(df['date'])

# %%
df
# Out:
#                   date  ind  rain  ind.1  temp  ind.2  wetb  dewpt  vappr  \
# 0    01-jan-1991 00:00    3   0.0      0   1.5      0   1.0    0.2    6.2
# 1    01-jan-1991 01:00    3   0.0      0   1.8      0   1.3    0.5    6.3
# 2    01-jan-1991 02:00    0   0.0      0   2.1      0   1.8    1.3    6.7
# 3    01-jan-1991 03:00    2   0.0      0   2.5      0   2.2    1.7    6.9
# 4    01-jan-1991 04:00    0   0.2      0   3.4      0   2.9    2.1    7.1
# ..                 ...  ...   ...    ...   ...    ...   ...    ...    ...
# 995  11-feb-1991 11:00    0   0.0      0   3.2      0   2.3    0.8    6.5
# 996  11-feb-1991 12:00    0   0.0      0   5.5      0   3.6    0.6    6.4
# 997  11-feb-1991 13:00    0   0.0      0   6.6      0   4.4    1.0    6.6
# 998  11-feb-1991 14:00    0   0.0      0   6.5      0   3.9   -0.2    6.0
# 999  11-feb-1991 15:00    0   0.0      0   6.0      0   3.5   -0.6    5.8
#
#      rhum     msl  ind.3  wdsp  ind.4  wddir            datetime
# ...

# %%
# Using the time stamp as index for data frame

# %%
import seaborn as sns

# %%
sns.lineplot(x='datetime', y="temp", data=df)
# Out:
# <AxesSubplot:xlabel='datetime', ylabel='temp'>
